# %% [markdown]
# <a href="https://colab.research.google.com/github/BenGravell/rbot101/blob/main/probability_theory/sigma_field.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code to create sigma fields
#
# The sigma_field is only equivalent to the powerset when the events generating the sigma field are the singleton events / outcomes.
#
# We must use the immutable 'frozenset' data type because the mutable 'set' data type cannot contain mutable objects.

# %%
from itertools import combinations

emptyset = frozenset()

# %%
def make_powerset(input_set):
    size = len(input_set)
    powerset = set([emptyset])
    for k in range(1, size + 1):
        for comb in combinations(input_set, k):
            powerset.add(frozenset(comb))
    return powerset

# %%
# Problem data
n = 8
sample_space = {i for i in range(n)}  # Single n-sided die roll

# %%
# Create the sigma field
sigma_field = make_powerset(sample_space)

# %%
# Choose some arbitrary events from the sample space
# Note these are zero-indexed
events = [{1}, {2, 3, 4, 5}, {1, 3, 5, 7}]

# %%
# Verify that events are in the sigma field
for event in events:
    assert event in sigma_field

# %%
# Verify the null and certain events are in the sigma field
for event in [emptyset, sample_space]:
    assert event in sigma_field

# %%
# Print the entire sigma field
for event in sigma_field:
    print(event)
# Out:
# frozenset({0, 1, 2, 3, 7})
# frozenset({2, 3})
# frozenset({0, 1, 7})
# frozenset({2, 3, 5, 6})
# frozenset({0, 2, 3, 6, 7})
# frozenset({0, 1, 4, 5, 6})
# frozenset({0, 2, 4})
# frozenset({0, 2, 3, 4, 6, 7})
# frozenset({3, 4, 5, 6, 7})
# frozenset({0, 3, 4, 6})
# frozenset({1, 2, 3, 4, 5, 6})
# frozenset({1, 2, 3, 4, 5, 6, 7})
# frozenset({0, 3, 4, 7})
# frozenset({1, 2, 3, 4, 5, 7})
# frozenset({1, 3, 4, 5, 6})
# frozenset({3, 4})
# frozenset({3, 4, 5, 6})
# frozenset({0, 4, 5, 6, 7})
# frozenset({0, 4, 6})
# frozenset({0, 1, 2, 3, 4, 6})
# frozenset({0, 1, 2, 3, 4})
# frozenset({0, 2, 3, 4})
# frozenset({0, 2})
# frozenset({1, 3, 7})
# frozenset({0, 2, 5, 6})
# frozenset({0, 2, 4, 5, 6})
# frozenset({2, 4})
# frozenset({2, 4, 5, 6})
# frozenset({1, 2, 4, 5, 6})
# frozenset({3, 4, 5})
# frozenset({0, 2, 4, 7})
# frozenset({0, 2, 3, 5, 7})
# frozenset({1, 2, 4, 5})
# frozenset({0, 1, 3, 5, 6})
# frozenset({4, 7})
# frozenset({4, 5, 6, 7})
# frozenset({0, 1, 2, 4, 6, 7})
# frozenset({2, 6, 7})
# frozenset({0, 1, 3, 5})
# frozenset({6, 7})
# frozenset({0, 1, 2, 3, 4, 5, 6, 7})
# frozenset({0, 1, 2, 3, 4, 5, 6})
# frozenset({1, 2, 5, 6, 7})
# frozenset({2, 7})
# frozenset({0, 1, 3})
# frozenset({2, 3, 4, 7})
# frozenset({2, 5, 6, 7})
# frozenset({0, 1, 3, 4, 5, 7})
# frozenset({2})
# frozenset({4, 6, 7})
# frozenset({1, 3, 6})
# frozenset({0, 2, 5, 7})
# frozenset({0, 1, 2, 5, 7})
# frozenset({0, 6, 7})
# frozenset({1, 2, 3, 5})
# frozenset({2, 5})
# frozenset({3})
# frozenset({1, 3, 4, 5, 7})
# frozenset({0, 1, 2, 4, 5, 7})
# frozenset({0, 1, 3, 4, 6})
# frozenset({1, 4, 6, 7})
# frozenset({0, 2, 4, 5, 6, 7})
# frozenset({0})
# frozenset({0, 4, 5, 7})
# frozenset({2, 3, 4})
# frozenset({4, 5})
# frozenset({0, 3, 4, 6, 7})
# frozenset({0, 1, 2, 4, 5, 6})
# frozenset({1, 2, 4, 7})
# frozenset({1, 5, 7})
# frozenset({0, 2, 3, 6})
# frozenset({0, 1, 2, 5, 6})
# frozenset({0, 3, 5})
# frozenset({1, 2, 6, 7})
# frozenset({0, 2, 4, 6, 7})
# frozenset({2, 3, 4, 6})
# frozenset({0, 1, 3, 4, 5, 6})
# frozenset({1, 2, 3, 4, 6})
# frozenset({1, 4, 6})
# frozenset({1, 7})
# frozenset({0, 2, 3})
# frozenset({1, 5, 6, 7})
# frozenset({0, 3})
# frozenset({1, 2, 7})
# frozenset({0, 3, 5, 6})
# frozenset({0, 2, 3, 4, 5, 6, 7})
# frozenset({1, 4, 5, 7})
# frozenset({2, 3, 5})
# frozenset({0, 1, 6, 7})
# frozenset({0, 3, 5, 6, 7})
# frozenset({3, 5})
# frozenset({0, 1, 2, 3, 5, 6})
# frozenset({1, 6})
# frozenset({0, 1, 3, 5, 7})
# frozenset({1, 2, 6})
# frozenset({0, 3, 5, 7})
# frozenset({2, 4, 5, 6, 7})
# frozenset({0, 3, 4})
# frozenset({2, 4, 5, 7})
# frozenset({1, 2, 3, 4, 7})
# frozenset({2, 3, 4, 5})
# frozenset({1, 4, 5})
# frozenset({2, 3, 4, 5, 6})
# frozenset({1, 3, 4, 5, 6, 7})
# frozenset({0, 1, 3, 4})
# frozenset({5})
# frozenset({3, 4, 5, 7})
# frozenset({0, 1, 2, 3, 4, 7})
# frozenset({5, 7})
# frozenset({0, 1, 2, 5, 6, 7})
# frozenset({2, 5, 7})
# frozenset({0, 1, 3, 6})
# frozenset({0, 1, 3, 4, 7})
# frozenset({1, 3, 4, 5})
# frozenset({2, 4, 5})
# frozenset({2, 3, 4, 5, 6, 7})
# frozenset({0, 1, 3, 6, 7})
# frozenset({5, 6, 7})
# frozenset({0, 1, 2, 3})
# frozenset({1, 2, 3, 5, 7})
# frozenset({2, 3, 5, 6, 7})
# frozenset()
# frozenset({2, 4, 6, 7})
# frozenset({0, 1, 4, 5, 6, 7})
# frozenset({0, 1, 2, 3, 6})
# frozenset({0, 5, 7})
# frozenset({1, 2, 3, 6})
# frozenset({1, 3, 5})
# frozenset({0, 2, 6, 7})
# frozenset({2, 6})
# frozenset({0, 2, 5})
# frozenset({1, 3, 6, 7})
# frozenset({1, 3, 4, 6, 7})
# frozenset({0, 5})
# frozenset({0, 2, 3, 5, 6, 7})
# frozenset({0, 3, 4, 5})
# frozenset({1})
# frozenset({0, 1, 3, 4, 5})
# frozenset({0, 1, 2, 3, 5, 6, 7})
# frozenset({1, 3, 4, 7})
# frozenset({0, 2, 3, 4, 5, 7})
# frozenset({1, 3, 4, 6})
# frozenset({0, 2, 3, 4, 5, 6})
# frozenset({0, 3, 4, 5, 7})
# frozenset({2, 4, 6})
# frozenset({1, 4, 7})
# frozenset({1, 3, 5, 6, 7})
# frozenset({2, 3, 4, 6, 7})
# frozenset({0, 4, 5})
# frozenset({0, 1, 2, 4, 6})
# frozenset({0, 3, 6})
# frozenset({1, 2, 5, 7})
# frozenset({0, 2, 3, 4, 5})
# frozenset({1, 6, 7})
# frozenset({0, 2, 3, 5})
# frozenset({1, 2, 4, 5, 7})
# frozenset({1, 2, 3, 4, 5})
# frozenset({3, 4, 6})
# frozenset({0, 2, 4, 5, 7})
# frozenset({1, 2, 4, 6})
# frozenset({1, 2, 3, 5, 6})
# frozenset({1, 3, 4})
# frozenset({0, 1, 2, 4, 5, 6, 7})
# frozenset({0, 1, 4, 5})
# frozenset({3, 7})
# frozenset({0, 1, 2})
# frozenset({3, 5, 6, 7})
# frozenset({0, 1})
# frozenset({3, 6})
# frozenset({2, 3, 7})
# frozenset({0, 1, 5, 6})
# frozenset({2, 3, 6})
# frozenset({0, 1, 5, 7})
# frozenset({0, 1, 4, 5, 7})
# frozenset({1, 2, 5})
# frozenset({0, 3, 6, 7})
# frozenset({1, 2, 3, 5, 6, 7})
# frozenset({1, 5})
# frozenset({0, 1, 5, 6, 7})
# frozenset({0, 1, 6})
# frozenset({2, 3, 5, 7})
# frozenset({3, 6, 7})
# frozenset({0, 1, 2, 5})
# frozenset({4, 5, 7})
# frozenset({0, 1, 4})
# frozenset({0, 1, 2, 6, 7})
# frozenset({0, 1, 3, 4, 6, 7})
# frozenset({1, 2})
# frozenset({0, 3, 7})
# frozenset({1, 2, 5, 6})
# frozenset({3, 5, 6})
# frozenset({0, 1, 2, 7})
# frozenset({0, 1, 2, 4, 7})
# frozenset({0, 3, 4, 5, 6})
# frozenset({6})
# frozenset({0, 1, 4, 6})
# frozenset({1, 4, 5, 6, 7})
# frozenset({0, 4, 6, 7})
# frozenset({1, 2, 4, 5, 6, 7})
# frozenset({1, 4})
# frozenset({4, 6})
# frozenset({1, 4, 5, 6})
# frozenset({0, 1, 4, 7})
# frozenset({0, 2, 4, 6})
# frozenset({0, 5, 6})
# frozenset({1, 2, 3, 7})
# frozenset({0, 3, 4, 5, 6, 7})
# frozenset({0, 1, 3, 4, 5, 6, 7})
# frozenset({4, 5, 6})
# frozenset({0, 2, 3, 4, 7})
# frozenset({0, 2, 5, 6, 7})
# frozenset({0, 4, 7})
# frozenset({0, 6})
# frozenset({0, 1, 2, 3, 4, 6, 7})
# frozenset({0, 2, 6})
# frozenset({1, 3, 5, 7})
# frozenset({0, 4})
# frozenset({0, 4, 5, 6})
# frozenset({5, 6})
# frozenset({2, 5, 6})
# frozenset({0, 1, 3, 7})
# frozenset({0, 7})
# frozenset({1, 2, 3})
# frozenset({0, 5, 6, 7})
# frozenset({1, 3})
# frozenset({0, 2, 7})
# frozenset({1, 3, 5, 6})
# frozenset({0, 1, 2, 4, 5})
# frozenset({0, 1, 2, 3, 6, 7})
# frozenset({0, 2, 4, 5})
# frozenset({2, 3, 4, 5, 7})
# frozenset({1, 2, 4, 6, 7})
# frozenset({3, 4, 7})
# frozenset({0, 2, 3, 4, 6})
# frozenset({1, 2, 3, 4})
# frozenset({3, 4, 6, 7})
# frozenset({0, 1, 2, 3, 4, 5, 7})
# frozenset({2, 4, 7})
# frozenset({4})
# frozenset({0, 1, 2, 3, 5, 7})
# frozenset({1, 2, 4})
# frozenset({0, 2, 3, 7})
# frozenset({0, 1, 4, 6, 7})
# frozenset({1, 2, 3, 4, 6, 7})
# frozenset({0, 1, 2, 3, 4, 5})
# frozenset({7})
# frozenset({3, 5, 7})
# frozenset({0, 1, 2, 6})
# frozenset({1, 2, 3, 6, 7})
# frozenset({0, 1, 5})
# frozenset({2, 3, 6, 7})
# frozenset({0, 1, 3, 5, 6, 7})
# frozenset({0, 2, 3, 5, 6})
# frozenset({0, 1, 2, 3, 5})
# frozenset({0, 1, 2, 4})
# frozenset({1, 5, 6})
